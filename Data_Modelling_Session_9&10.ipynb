# %% [markdown]
# # <center>Data Modeling - Session 9&10 </center>
# <img src="https://datasemantics.co/wp-content/uploads/2021/01/it-heads-guide-to-data-modelling.jpg">
#
#
#
#
# Here are the things we will do in these sessions:
#
# 1.   Pandas
# 2.   More Data Visualization
#
# <br><br>

# %% [markdown]
# #<center>PANDAS
#
# <img src=https://www.adictosaltrabajo.com/wp-content/uploads/2020/12/1200px-Pandas_logo.svg_-1068x432.png width=400>
#
# <img src="https://images.seattletimes.com/wp-content/uploads/2018/03/03292018_Pandas_150403_tzr.jpg?d=780x501">

# %% [markdown]
# ## What is Pandas?
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.<br>
#
# ##Library Highlights
# - A fast and efficient DataFrame object for data manipulation with integrated indexing;
#
# - Tools for reading and writing data between in-memory data structures and different formats: CSV and text files, Microsoft Excel, SQL databases, and the fast HDF5 format;
#
# - Intelligent data alignment and integrated handling of missing data: gain automatic label-based alignment in computations and easily manipulate messy data into an orderly form;
#
# - Flexible reshaping and pivoting of data sets;
#
# - Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
#
# - Columns can be inserted and deleted from data structures for size mutability;
#
# - Aggregating or transforming data with a powerful group by engine allowing split-apply-combine operations on data sets;
#
# - High performance merging and joining of data sets;
#
# - Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
#
# - Time series-functionality: date range generation and frequency conversion, moving window statistics, date shifting and lagging. Even create domain-specific time offsets and join time series without losing data;
#
# - Highly optimized for performance, with critical code paths written in Cython or C.
#
# - Python with pandas is in use in a wide variety of academic and commercial domains, including Finance, Neuroscience, Economics, Statistics, Advertising, Web Analytics, and more.
#
# ##Mission
# Pandas aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.
#
# ##Vision
# A world where data analytics and manipulation software is:
#
# - Accessible to everyone
# - Free for users to use and modify
# - Flexible
# - Powerful
# - Easy to use
# - Fast

# %% [markdown]
# ## Where to learn about Pandas?
#
# <img src=https://assets.entrepreneur.com/content/3x2/2000/20181119204233-GettyImages-140892148-edit.jpeg width=400>
#
#
# [Pandas Website](https://pandas.pydata.org/)
#
# Let's go over an introduction to Pandas from the official website:<br>
# [10 Minutes to Pandas*](https://pandas.pydata.org/docs/user_guide/10min.html) <br>
# <sub> \*more like 30+ minutes </sub>

# %% [markdown]
# ## IE Students when they need to learn by themselves

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://media1.tenor.com/m/xrUe4KFY0dsAAAAC/brother-ew-ew.gif" width="800">')

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://i.imgflip.com/7dsbg9.jpg" width="800">')

# %%
# these are the imports
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=[1,2,4,5,6,9])
print(s)
print(s[4])
print(s[9])
print(s.index)
print(s.values)
# Out:
# 1    1.0
# 2    3.0
# 4    5.0
# 5    NaN
# 6    6.0
# 9    8.0
# dtype: float64
# 5.0
# 8.0
# Index([1, 2, 4, 5, 6, 9], dtype='int64')
# [ 1.  3.  5. nan  6.  8.]

# %%
dates = pd.date_range("20240425", periods=6, freq="MS")

df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
# df = pd.DataFrame(np.random.randint(1, 100, (6, 4)), index=dates, columns=list("ABCD"))

df

# df.T.index
# Out:
#                    A         B         C         D
# 2024-05-01 -0.787552 -0.324502  0.666818  1.317047
# 2024-06-01 -1.327360  1.187726  0.509624  0.825749
# 2024-07-01 -0.101401  0.897089  0.004200  0.420109
# 2024-08-01 -0.497388  0.380055  0.615006  0.195595
# 2024-09-01 -1.864885 -1.401702  0.810600 -0.608266
# 2024-10-01 -0.199355 -0.342763 -0.298218 -0.254678

# %%
dates = pd.date_range("20240425", periods=10, freq="B")

df = pd.DataFrame(np.random.randn(10, 5), index=dates, columns=list("azbyx"))
# df = pd.DataFrame(np.random.randint(1, 300, (10, 5)), index=dates, columns=list("azbyx"))

df

# df.T.index
# Out:
#                    a         z         b         y         x
# 2024-04-25 -1.972755 -1.686003  0.507420 -0.955288 -1.874545
# 2024-04-26 -0.066989 -2.008125  0.073079 -0.778098  0.015607
# 2024-04-29  0.845220 -1.756608 -2.072653 -0.901533 -0.768692
# 2024-04-30  2.159544  0.822971 -1.054657  0.877134 -1.913826
# 2024-05-01  0.607691 -0.325738 -0.166770  2.209476 -2.159861
# 2024-05-02 -1.046421 -2.136169 -0.812374  0.309653  0.498943
# 2024-05-03 -1.840347 -0.747368 -1.414590 -1.171845  0.180051
# 2024-05-06 -0.558273 -1.134046  0.307291 -0.499740 -1.014454
# 2024-05-07  2.255504  0.912859 -1.561353  0.404035 -1.428248
# 2024-05-08  0.612619 -0.744937  0.388692  1.065627 -0.328657

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["testing", "training", "testing", "training"]),
        "F": "foo"
    }
)
df2
# Out:
#      A          B    C  D         E    F
# 0  1.0 2013-01-02  1.0  3   testing  foo
# 1  1.0 2013-01-02  1.0  3  training  foo
# 2  1.0 2013-01-02  1.0  3   testing  foo
# 3  1.0 2013-01-02  1.0  3  training  foo

# %%
print(df.index)
print("-----")
df.describe()
# Out:
# DatetimeIndex(['2024-04-25', '2024-04-26', '2024-04-29', '2024-04-30',
#                '2024-05-01', '2024-05-02', '2024-05-03', '2024-05-06',
#                '2024-05-07', '2024-05-08'],
#               dtype='datetime64[ns]', freq='B')
# -----
#                a          z          b          y          x
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.099579  -0.880316  -0.580592   0.055942  -0.879368
# std     1.483260   1.094976   0.923297   1.103946   0.952090
# min    -1.972755  -2.136169  -2.072653  -1.171845  -2.159861
# 25%    -0.924384  -1.738957  -1.324607  -0.870674  -1.762970
# 50%     0.270351  -0.940707  -0.489572  -0.095044  -0.891573
# 75%     0.787069  -0.430538   0.248738   0.758860  -0.070459
# max     2.255504   0.912859   0.507420   2.209476   0.498943

# %%
print(df.T)

print(df.sort_values(by="a", ascending=True))
print(df)
# Out:
#    2024-04-25  2024-04-26  2024-04-29  2024-04-30  2024-05-01  2024-05-02  \
# a   -1.972755   -0.066989    0.845220    2.159544    0.607691   -1.046421
# z   -1.686003   -2.008125   -1.756608    0.822971   -0.325738   -2.136169
# b    0.507420    0.073079   -2.072653   -1.054657   -0.166770   -0.812374
# y   -0.955288   -0.778098   -0.901533    0.877134    2.209476    0.309653
# x   -1.874545    0.015607   -0.768692   -1.913826   -2.159861    0.498943
#
#    2024-05-03  2024-05-06  2024-05-07  2024-05-08
# a   -1.840347   -0.558273    2.255504    0.612619
# z   -0.747368   -1.134046    0.912859   -0.744937
# b   -1.414590    0.307291   -1.561353    0.388692
# y   -1.171845   -0.499740    0.404035    1.065627
# x    0.180051   -1.014454   -1.428248   -0.328657
#                    a         z         b         y         x
# 2024-04-25 -1.972755 -1.686003  0.507420 -0.955288 -1.874545
# 2024-05-03 -1.840347 -0.747368 -1.414590 -1.171845  0.180051
# 2024-05-02 -1.046421 -2.136169 -0.812374  0.309653  0.498943
# 2024-05-06 -0.558273 -1.134046  0.307291 -0.499740 -1.014454
# 2024-04-26 -0.066989 -2.008125  0.073079 -0.778098  0.015607
# 2024-05-01  0.607691 -0.325738 -0.166770  2.209476 -2.159861
# 2024-05-08  0.612619 -0.744937  0.388692  1.065627 -0.328657
# 2024-04-29  0.845220 -1.756608 -2.072653 -0.901533 -0.768692
# 2024-04-30  2.159544  0.822971 -1.054657  0.877134 -1.913826
# 2024-05-07  2.255504  0.912859 -1.561353  0.404035 -1.428248
#                    a         z         b         y         x
# 2024-04-25 -1.972755 -1.686003  0.507420 -0.955288 -1.874545
# 2024-04-26 -0.066989 -2.008125  0.073079 -0.778098  0.015607
# 2024-04-29  0.845220 -1.756608 -2.072653 -0.901533 -0.768692
# 2024-04-30  2.159544  0.822971 -1.054657  0.877134 -1.913826
# 2024-05-01  0.607691 -0.325738 -0.166770  2.209476 -2.159861
# 2024-05-02 -1.046421 -2.136169 -0.812374  0.309653  0.498943
# 2024-05-03 -1.840347 -0.747368 -1.414590 -1.171845  0.180051
# 2024-05-06 -0.558273 -1.134046  0.307291 -0.499740 -1.014454
# 2024-05-07  2.255504  0.912859 -1.561353  0.404035 -1.428248
# 2024-05-08  0.612619 -0.744937  0.388692  1.065627 -0.328657

# %% [markdown]
# ## Selection

# %%
print(df)
print(df["a"]) # df.A dot notation
print("----")
print(type(df.a))
print(df.a.values)
# Out:
#                    a         z         b         y         x
# 2024-04-25 -1.972755 -1.686003  0.507420 -0.955288 -1.874545
# 2024-04-26 -0.066989 -2.008125  0.073079 -0.778098  0.015607
# 2024-04-29  0.845220 -1.756608 -2.072653 -0.901533 -0.768692
# 2024-04-30  2.159544  0.822971 -1.054657  0.877134 -1.913826
# 2024-05-01  0.607691 -0.325738 -0.166770  2.209476 -2.159861
# 2024-05-02 -1.046421 -2.136169 -0.812374  0.309653  0.498943
# 2024-05-03 -1.840347 -0.747368 -1.414590 -1.171845  0.180051
# 2024-05-06 -0.558273 -1.134046  0.307291 -0.499740 -1.014454
# 2024-05-07  2.255504  0.912859 -1.561353  0.404035 -1.428248
# 2024-05-08  0.612619 -0.744937  0.388692  1.065627 -0.328657
# 2024-04-25   -1.972755
# 2024-04-26   -0.066989
# 2024-04-29    0.845220
# 2024-04-30    2.159544
# 2024-05-01    0.607691
# 2024-05-02   -1.046421
# 2024-05-03   -1.840347
# 2024-05-06   -0.558273
# 2024-05-07    2.255504
# 2024-05-08    0.612619
# Freq: B, Name: a, dtype: float64
# ----
# <class 'pandas.core.series.Series'>
# [-1.9727554  -0.06698934  0.84521967  2.15954395  0.60769083 -1.04642124
#  -1.84034656 -0.5582729   2.25550374  0.61261877]

# %%
# slice
df[1:3]["b"]
# Out:
# 2024-04-26    0.073079
# 2024-04-29   -2.072653
# Freq: B, Name: b, dtype: float64

# %%
# selection withb loc (by value)

dates[1] # this is the index for the second row
print(df)
print("-----")
print(df.loc[dates[1]])
# Out:
#                    a         z         b         y         x
# 2024-04-25 -1.972755 -1.686003  0.507420 -0.955288 -1.874545
# 2024-04-26 -0.066989 -2.008125  0.073079 -0.778098  0.015607
# 2024-04-29  0.845220 -1.756608 -2.072653 -0.901533 -0.768692
# 2024-04-30  2.159544  0.822971 -1.054657  0.877134 -1.913826
# 2024-05-01  0.607691 -0.325738 -0.166770  2.209476 -2.159861
# 2024-05-02 -1.046421 -2.136169 -0.812374  0.309653  0.498943
# 2024-05-03 -1.840347 -0.747368 -1.414590 -1.171845  0.180051
# 2024-05-06 -0.558273 -1.134046  0.307291 -0.499740 -1.014454
# 2024-05-07  2.255504  0.912859 -1.561353  0.404035 -1.428248
# 2024-05-08  0.612619 -0.744937  0.388692  1.065627 -0.328657
# -----
# a   -0.066989
# z   -2.008125
# b    0.073079
# y   -0.778098
# x    0.015607
# Name: 2024-04-26 00:00:00, dtype: float64

# %%
# multiple selection with loc
print(df)
print("------")
print(df.loc[[df.index[1],dates[4]], ["a", "y"]])
# Out:
#                    a         z         b         y         x
# 2024-04-25 -1.972755 -1.686003  0.507420 -0.955288 -1.874545
# 2024-04-26 -0.066989 -2.008125  0.073079 -0.778098  0.015607
# 2024-04-29  0.845220 -1.756608 -2.072653 -0.901533 -0.768692
# 2024-04-30  2.159544  0.822971 -1.054657  0.877134 -1.913826
# 2024-05-01  0.607691 -0.325738 -0.166770  2.209476 -2.159861
# 2024-05-02 -1.046421 -2.136169 -0.812374  0.309653  0.498943
# 2024-05-03 -1.840347 -0.747368 -1.414590 -1.171845  0.180051
# 2024-05-06 -0.558273 -1.134046  0.307291 -0.499740 -1.014454
# 2024-05-07  2.255504  0.912859 -1.561353  0.404035 -1.428248
# 2024-05-08  0.612619 -0.744937  0.388692  1.065627 -0.328657
# ------
#                    a         y
# 2024-04-26 -0.066989 -0.778098
# 2024-05-01  0.607691  2.209476

# %%
df = pd.DataFrame(np.random.randn(5, 5), index=[1, 2, 3, 4, 5], columns=list("ABCDE"))
df
# Out:
#           A         B         C         D         E
# 1  0.341751 -0.228512  0.685913 -1.516030 -1.110549
# 2  1.197256 -2.093147 -1.633541 -0.395364 -0.148983
# 3  0.501710 -0.366596  0.593792  0.236523  0.043395
# 4 -0.307824  0.737849  0.769651 -1.073474  0.153988
# 5 -0.287458 -0.301456 -1.438155  0.815270 -0.114547

# %%
df.loc[[3,1], ["C", "D"]]
# Out:
#           C         D
# 3  0.593792  0.236523
# 1  0.685913 -1.516030

# %%
df.loc[[3], ["E"]]
# Out:
#           E
# 3  0.043395

# %% [markdown]
# ## Selection by position (iloc)

# %%
print(df)
print("----")
print(df.iloc[1])
print("----")
print(df.iloc[1:3, 1:2])
print("----")
print(df.iloc[[0,2,4], [1,3]])
# Out:
#           A         B         C         D         E
# 1  0.216082  0.318945 -0.111484  1.187918  0.252003
# 2  1.187672 -1.269258 -0.621438  0.379646 -1.085539
# 3  0.572443 -1.837072 -1.563646 -0.306506 -0.896812
# 4 -0.306084 -2.433180 -0.069006  0.863736  1.760188
# 5  0.438085 -1.296594 -1.003053  1.152084 -0.208075
# ----
# A    1.187672
# B   -1.269258
# C   -0.621438
# D    0.379646
# E   -1.085539
# Name: 2, dtype: float64
# ----
#           B
# 2 -1.269258
# 3 -1.837072
# ----
#           B         D
# 1  0.318945  1.187918
# 3 -1.837072 -0.306506
# 5 -1.296594  1.152084

# %%
# boolean indexing
print(df)
print("---")
print(df[df["A"] > 0])
# Out:
#           A         B         C         D         E
# 1  0.341751 -0.228512  0.685913 -1.516030 -1.110549
# 2  1.197256 -2.093147 -1.633541 -0.395364 -0.148983
# 3  0.501710 -0.366596  0.593792  0.236523  0.043395
# 4 -0.307824  0.737849  0.769651 -1.073474  0.153988
# 5 -0.287458 -0.301456 -1.438155  0.815270 -0.114547
# ---
#           A         B         C         D         E
# 1  0.341751 -0.228512  0.685913 -1.516030 -1.110549
# 2  1.197256 -2.093147 -1.633541 -0.395364 -0.148983
# 3  0.501710 -0.366596  0.593792  0.236523  0.043395

# %% [markdown]
# Adding data

# %%
df["E"] = ["whip", "booze"] * 2 + ["cruise"]
df["Peter Griffin"] = [7] * 5
df["Peter Griffin"] = 11
print(df)
# Out:
#           A         B         C         D       E  Peter Griffin
# 1  0.341751 -0.228512  0.685913 -1.516030    whip             11
# 2  1.197256 -2.093147 -1.633541 -0.395364   booze             11
# 3  0.501710 -0.366596  0.593792  0.236523    whip             11
# 4 -0.307824  0.737849  0.769651 -1.073474   booze             11
# 5 -0.287458 -0.301456 -1.438155  0.815270  cruise             11

# %%
import matplotlib.pylab as plt
print(df)

#

plt.plot(df.index, df.A)

# df[['D', 'C']].plot()
# Out:
#           A         B         C         D       E  Peter Griffin
# 1  0.341751 -0.228512  0.685913 -1.516030    whip             11
# 2  1.197256 -2.093147 -1.633541 -0.395364   booze             11
# 3  0.501710 -0.366596  0.593792  0.236523    whip             11
# 4 -0.307824  0.737849  0.769651 -1.073474   booze             11
# 5 -0.287458 -0.301456 -1.438155  0.815270  cruise             11

# %% [markdown]
# #<center> Practical Example
# Apple stock over the years and the launch of Iphones
#
# ![](https://drive.google.com/uc?id=1RGgV6RcSuNFNZ11RCRxs3ms0K9oXwJrH)

# %%
# !pip install --upgrade pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (4.9.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.23->pandas-datareader) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.2.2)

# %%
import requests

r = requests.get("https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates-2019.xlsx")
with open("sample_data/launch.xlsx", "wb") as f:
  f.write(r.content)

# %%
# !wget https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates-2019.xlsx -O sample_data/launch2.xlsx
# Out:
# --2024-04-25 15:26:50--  https://github.com/itb-ie/pandas-apple-stock/raw/master/iphone-dates-2019.xlsx
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/itb-ie/pandas-apple-stock/master/iphone-dates-2019.xlsx [following]
# --2024-04-25 15:26:50--  https://raw.githubusercontent.com/itb-ie/pandas-apple-stock/master/iphone-dates-2019.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10992 (11K) [application/octet-stream]
# Saving to: ‘sample_data/launch2.xlsx’
#
# sample_data/launch2 100%[===================>]  10.73K  --.-KB/s    in 0s
#
# 2024-04-25 15:26:50 (62.2 MB/s) - ‘sample_data/launch2.xlsx’ saved [10992/10992]

# %%
from matplotlib import pylab as plt
import pandas as pd
import pandas_datareader.data as web
import yfinance as yfin

yfin.pdr_override()

df1 = web.DataReader('AAPL', start='2006-01-01', end='2024-04-01')
df2 = pd.read_excel("sample_data/launch.xlsx")

df2['Date'] = pd.to_datetime(df2.date)
df1['Date'] = pd.to_datetime(df1.index)
df1.insert(0, 'ID', range(0, len(df1)))
print(df1)

index2 = []
for date2 in df2.Date:
    if df1.ID[df1.Date == date2].values.size:
        index2.append(int(df1.ID[df1.Date == date2].values[0]))
    elif df1.ID[df1.Date == date2 + pd.DateOffset(1)].values.size:
        index2.append(int(df1.ID[df1.Date == date2 + pd.DateOffset(1)].values[0]))
    elif df1.ID[df1.Date == date2 + pd.DateOffset(2)].values.size:
        index2.append(int(df1.ID[df1.Date == date2 + pd.DateOffset(2)].values[0]))

    else:
        print(f"Did not find {date2}")

print(index2)

plt.figure("Apple Stock")
plt.figure(figsize = (20, 10))
plt.plot(df1["Date"], df1["Close"], '-^', ms=11, mfc="red", linewidth=0.6,
         markevery=index2, label="Iphone launch date")
plt.xlabel("Dates")
plt.legend(loc="upper left")
plt.show()
df1.to_csv("sample_data/result.csv")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#               ID        Open        High         Low       Close   Adj Close  \
# Date
# 2006-01-03     0    2.585000    2.669643    2.580357    2.669643    2.260118
# 2006-01-04     1    2.683214    2.713571    2.660714    2.677500    2.266770
# 2006-01-05     2    2.672500    2.675000    2.633929    2.656429    2.248931
# 2006-01-06     3    2.687500    2.739286    2.662500    2.725000    2.306984
# 2006-01-09     4    2.740357    2.757143    2.705000    2.716071    2.299424
# ...          ...         ...         ...         ...         ...         ...
# 2024-03-22  4585  171.759995  173.050003  170.059998  172.279999  172.279999
# 2024-03-25  4586  170.570007  171.940002  169.449997  170.850006  170.850006
# 2024-03-26  4587  170.000000  171.419998  169.580002  169.710007  169.710007
# 2024-03-27  4588  170.410004  173.600006  170.110001  173.309998  173.309998
# 2024-03-28  4589  171.750000  172.229996  170.509995  171.479996  171.479996
#
#                Volume       Date
# Date
# 2006-01-03  807234400 2006-01-03
# 2006-01-04  619603600 2006-01-04
# 2006-01-05  449422400 2006-01-05
# 2006-01-06  704457600 2006-01-06
# 2006-01-09  675040800 2006-01-09
# ...               ...        ...
# 2024-03-22   71106600 2024-03-22
# 2024-03-25   54288300 2024-03-25
# 2024-03-26   57388400 2024-03-26
# 2024-03-27   60273300 2024-03-27
# 2024-03-28   65672700 2024-03-28
#
# [4590 rows x 8 columns]
# [3202, 3227, 2981, 2577, 2951, 2695, 2445, 2194, 1934, 1693, 1457, 1123, 871, 626, 3452, 425, 3728, 3959, 4205, 4460]

# %%
# Plotting using pandas' built-in functionality
ax = df1['Close'].plot(
    figsize=(20, 10),
    style='-ob',
    linewidth=0.6,
    markevery=index2,  # Highlight the launch dates
    markerfacecolor='red',
    markersize=11,
    label='Close Price'
)

# Highlight iPhone launch dates with vertical lines
for launch_date in df1.iloc[index2].index:
    ax.axvline(x=launch_date, color='gray', linestyle='--', linewidth=0.5)

# Labeling and legend
ax.set_xlabel("Date")
ax.set_ylabel("Close Price")
ax.set_title("Apple Stock Prices with iPhone Launch Dates Highlighted")
ax.legend(loc="upper left")

# Show the plot
plt.show()

# %%
from matplotlib import pylab as plt
import pandas as pd
import pandas_datareader.data as web

company = "TSLA"
df = web.DataReader(company, start='2024-01-01', end='2024-04-18')
# print(df)

plt.style.use("default")

plt.figure(f"{company} CandleStick", figsize=(20,10))
plt.title(f"{company} CandleStick")
# plt.plot(df.index, df.Close)
plt.vlines(x=df.index, ymin=df.Low, ymax=df.High, color="gray")

green = df[df.Open <= df.Close].copy()
green['Height'] = green.Close - green.Open

red = df[df.Open > df.Close].copy()
red['Height'] = red.Open - red.Close

plt.bar(x=green.index, height=green.Height, bottom=green.Open, color="green")
plt.bar(x=red.index, height=red.Height, bottom=red.Close, color="red")


plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
#@title GameStop Stock!
from matplotlib import pylab as plt
import pandas as pd
import pandas_datareader.data as web

company = "GME"
df = web.DataReader(company, start='2020-01-01', end='2024-01-01')
# print(df)

plt.style.use("default")

plt.figure(f"{company} CandleStick", figsize=(20,10))
plt.title(f"{company} CandleStick")
# plt.plot(df.index, df.Close)
plt.vlines(x=df.index, ymin=df.Low, ymax=df.High, color="darkblue")

green = df[df.Open <= df.Close].copy()
green['Height'] = green.Close - green.Open

red = df[df.Open > df.Close].copy()
red['Height'] = red.Open - red.Close

plt.bar(x=green.index, height=green.Height, bottom=green.Open, color="green")
plt.bar(x=red.index, height=red.Height, bottom=red.Close, color="red")


plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# Here are the things we will do in this session:
#
# More pandas!
#
# ![](https://i.natgeofe.com/n/1e38ab75-6d81-45e9-817c-3181a146165e/01pandainsemination_3x2.jpg?w=718&h=479)

# %%
from IPython.display import HTML

# Use the direct URL to the GIF
HTML('<img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">')
# Out:
# <img src="https://media.tenor.com/9icIB76KxhgAAAAC/captain-america-i-can-do-this-all-day.gif" width="800">

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")
print(df.info) # info - prints a summary of information about a DataFrame
# Out:
# <bound method DataFrame.info of         year      name   percent   sex
# 0       1880      John  0.081541   boy
# 1       1880   William  0.080511   boy
# 2       1880     James  0.050057   boy
# 3       1880   Charles  0.045167   boy
# 4       1880    George  0.043292   boy
# ...      ...       ...       ...   ...
# 257995  2008  Carleigh  0.000128  girl
# 257996  2008     Iyana  0.000128  girl
# 257997  2008    Kenley  0.000127  girl
# 257998  2008    Sloane  0.000127  girl
# 257999  2008   Elianna  0.000127  girl
#
# [258000 rows x 4 columns]>

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

# Filter data according to specific criteria
df_filtered = df[(df.year >= 1880) & (df.sex == "boy") & (df.percent > 0.04)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()
print(grouped)

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in ascending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=True)

# Display the results
print(sorted_mean_df.values)

# %%
import pandas as pd

# Load the data
df = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")

# Filter data according to specific criteria
df_filtered = df[(df.year <= 1990) & (df.sex == "girl") & (df.percent > 0.006)]

# Group by 'name' and calculate the mean of the 'percent' column only
grouped = df_filtered.groupby('name')['percent'].mean()

# Convert the Series back to DataFrame for further manipulation if necessary
mean_df = grouped.reset_index()

# Sort the data by 'percent' in descending order
sorted_mean_df = mean_df.sort_values(by="percent", ascending=False)

# Display the results
print(sorted_mean_df.values)

# %%
df = pd.read_json("https://covid.cdc.gov/covid-data-tracker/COVIDData/getAjaxData?id=us_trend_by_USA_v2")
df
# Out:
#      runid                           us_trend_by_Geography_v2
# 0     3203  {'Geography': 'USA', 'runid': 3203, 'week_endi...
# 1     3203  {'week_ending_date': '2020-01-11', 'state': 'U...
# 2     3203  {'week_ending_date': '2020-01-18', 'state': 'U...
# 3     3203  {'week_ending_date': '2020-01-25', 'state': 'U...
# 4     3203  {'week_ending_date': '2020-02-01', 'state': 'U...
# ..     ...                                                ...
# 219   3203  {'week_ending_date': '2024-03-16', 'state': 'U...
# 220   3203  {'week_ending_date': '2024-03-23', 'state': 'U...
# 221   3203  {'week_ending_date': '2024-03-30', 'state': 'U...
# 222   3203  {'week_ending_date': '2024-04-06', 'state': 'U...
# 223   3203  {'week_ending_date': '2024-04-13', 'state': 'U...
#
# [224 rows x 2 columns]

# %%
df2 = df['us_trend_by_Geography_v2'].apply(pd.Series)
df2
# Out:
#     Geography   runid week_ending_date state  \
# 0         USA  3203.0       2020-01-04   USA
# 1         NaN     NaN       2020-01-11   USA
# 2         NaN     NaN       2020-01-18   USA
# 3         NaN     NaN       2020-01-25   USA
# 4         NaN     NaN       2020-02-01   USA
# ..        ...     ...              ...   ...
# 219       NaN     NaN       2024-03-16   USA
# 220       NaN     NaN       2024-03-23   USA
# 221       NaN     NaN       2024-03-30   USA
# 222       NaN     NaN       2024-04-06   USA
# 223       NaN     NaN       2024-04-13   USA
#
#      total_adm_all_covid_confirmed_past_7days  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 219                                   10918.0
# 220                                    9479.0
# 221                                    8131.0
# 222                                    7433.0
# 223                                    6406.0
#
#      avg_total_patients_hospitalized_covid_confirmed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 219                                         10371.29
# 220                                          8712.57
# 221                                          7521.43
# 222                                          6685.86
# 223                                          5899.00
#
#      sum_adm_all_covid_confirmed  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 219                    6892679.0
# 220                    6902158.0
# 221                    6910289.0
# 222                    6917722.0
# 223                    6924128.0
#
#      total_adm_all_covid_confirmed_past_7days_per_100k  data_as_of  \
# 0                                                  NaN  2024-04-18
# 1                                                  NaN  2024-04-18
# 2                                                  NaN  2024-04-18
# 3                                                  NaN  2024-04-18
# 4                                                  NaN  2024-04-18
# ..                                                 ...         ...
# 219                                               3.29  2024-04-18
# 220                                               2.86  2024-04-18
# 221                                               2.45  2024-04-18
# 222                                               2.24  2024-04-18
# 223                                               1.93  2024-04-18
#
#      COVID_deaths_weekly  COVID_deaths_total  crude_COVID_rate_weekly  \
# 0                      0                   0                      0.0
# 1                      1                   1                      NaN
# 2                      2                   3                      NaN
# 3                      3                   6                      NaN
# 4                      0                   6                      0.0
# ..                   ...                 ...                      ...
# 219                  982             1186913                      0.3
# 220                  779             1187692                      0.2
# 221                  601             1188293                      0.2
# 222                  455             1188748                      0.1
# 223                  243             1188991                      0.1
#
#      aa_COVID_rate_weekly  crude_COVID_rate_total  aa_COVID_rate_total  \
# 0                     0.0                     0.0                  0.0
# 1                     NaN                     NaN                  NaN
# 2                     NaN                     NaN                  NaN
# 3                     NaN                     NaN                  NaN
# 4                     0.0                     NaN                  NaN
# ..                    ...                     ...                  ...
# 219                   0.2                   357.6                297.2
# 220                   0.2                   357.9                297.4
# 221                   0.2                   358.0                297.5
# 222                   0.1                   358.2                297.6
# 223                   0.1                   358.2                297.7
#
#      COVID_pct_of_total_weekly  number_tested  percent_pos
# 0                          0.0            NaN          NaN
# 1                          0.0            NaN          NaN
# 2                          0.0            NaN          NaN
# 3                          0.0            NaN          NaN
# 4                          0.0            NaN          NaN
# ..                         ...            ...          ...
# 219                        1.7        90412.0          4.7
# 220                        1.4        80879.0          4.1
# 221                        1.2        75090.0          3.8
# 222                        1.1        64800.0          3.5
# 223                        1.0        49499.0          3.4
#
# [224 rows x 18 columns]

# %%
# remove Geography, runid
df2.drop(columns=["Geography", "runid"], inplace=True) # in place means there is no need to assign to another df
df2
# Out:
#     week_ending_date state  total_adm_all_covid_confirmed_past_7days  \
# 0         2020-01-04   USA                                       NaN
# 1         2020-01-11   USA                                       NaN
# 2         2020-01-18   USA                                       NaN
# 3         2020-01-25   USA                                       NaN
# 4         2020-02-01   USA                                       NaN
# ..               ...   ...                                       ...
# 219       2024-03-16   USA                                   10918.0
# 220       2024-03-23   USA                                    9479.0
# 221       2024-03-30   USA                                    8131.0
# 222       2024-04-06   USA                                    7433.0
# 223       2024-04-13   USA                                    6406.0
#
#      avg_total_patients_hospitalized_covid_confirmed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 219                                         10371.29
# 220                                          8712.57
# 221                                          7521.43
# 222                                          6685.86
# 223                                          5899.00
#
#      sum_adm_all_covid_confirmed  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 219                    6892679.0
# 220                    6902158.0
# 221                    6910289.0
# 222                    6917722.0
# 223                    6924128.0
#
#      total_adm_all_covid_confirmed_past_7days_per_100k  data_as_of  \
# 0                                                  NaN  2024-04-18
# 1                                                  NaN  2024-04-18
# 2                                                  NaN  2024-04-18
# 3                                                  NaN  2024-04-18
# 4                                                  NaN  2024-04-18
# ..                                                 ...         ...
# 219                                               3.29  2024-04-18
# 220                                               2.86  2024-04-18
# 221                                               2.45  2024-04-18
# 222                                               2.24  2024-04-18
# 223                                               1.93  2024-04-18
#
#      COVID_deaths_weekly  COVID_deaths_total  crude_COVID_rate_weekly  \
# 0                      0                   0                      0.0
# 1                      1                   1                      NaN
# 2                      2                   3                      NaN
# 3                      3                   6                      NaN
# 4                      0                   6                      0.0
# ..                   ...                 ...                      ...
# 219                  982             1186913                      0.3
# 220                  779             1187692                      0.2
# 221                  601             1188293                      0.2
# 222                  455             1188748                      0.1
# 223                  243             1188991                      0.1
#
#      aa_COVID_rate_weekly  crude_COVID_rate_total  aa_COVID_rate_total  \
# 0                     0.0                     0.0                  0.0
# 1                     NaN                     NaN                  NaN
# 2                     NaN                     NaN                  NaN
# 3                     NaN                     NaN                  NaN
# 4                     0.0                     NaN                  NaN
# ..                    ...                     ...                  ...
# 219                   0.2                   357.6                297.2
# 220                   0.2                   357.9                297.4
# 221                   0.2                   358.0                297.5
# 222                   0.1                   358.2                297.6
# 223                   0.1                   358.2                297.7
#
#      COVID_pct_of_total_weekly  number_tested  percent_pos
# 0                          0.0            NaN          NaN
# 1                          0.0            NaN          NaN
# 2                          0.0            NaN          NaN
# 3                          0.0            NaN          NaN
# 4                          0.0            NaN          NaN
# ..                         ...            ...          ...
# 219                        1.7        90412.0          4.7
# 220                        1.4        80879.0          4.1
# 221                        1.2        75090.0          3.8
# 222                        1.1        64800.0          3.5
# 223                        1.0        49499.0          3.4
#
# [224 rows x 16 columns]

# %%
# @title Graph Showing - total_adm_all_covid_confirmed_past_7days VS avg_total_patients_hospitalized_covid_confirmed

from matplotlib import pyplot as plt
df2.plot(kind='scatter', x='total_adm_all_covid_confirmed_past_7days', y='avg_total_patients_hospitalized_covid_confirmed', s=40, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df3 = df2.set_index(keys="week_ending_date")
df3
df3.index

df3.index = pd.to_datetime(df3.index)

# %%
df3.index
# Out:
# DatetimeIndex(['2020-01-04', '2020-01-11', '2020-01-18', '2020-01-25',
#                '2020-02-01', '2020-02-08', '2020-02-15', '2020-02-22',
#                '2020-02-29', '2020-03-07',
#                ...
#                '2024-02-10', '2024-02-17', '2024-02-24', '2024-03-02',
#                '2024-03-09', '2024-03-16', '2024-03-23', '2024-03-30',
#                '2024-04-06', '2024-04-13'],
#               dtype='datetime64[ns]', name='week_ending_date', length=224, freq=None)

# %%
import matplotlib.pyplot as plt
plt.ticklabel_format(style='sci') # Its using scientific notation
df3['COVID_deaths_total'].plot(figsize=(10, 15))
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
print(df3.info)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

df4 = filtered_df = df3[(df3.index.year == 2023) | (df3.index.year == 2024)] # I filtered it so it only shows from 2023 to 2024

# Plotting
plt.ticklabel_format(style='plain')
df4['COVID_deaths_weekly'].plot(figsize=(50, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
new_df = df3.loc[:, ['total_adm_all_covid_confirmed_past_7days', 'COVID_deaths_weekly']]
new_df['COVID_deaths_weekly'] *= 4
new_df = new_df.iloc[30:100]
# plt.ticklabel_format(style='plain')
new_df.plot(figsize=(20, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
new_df = df3.loc[:, ['total_adm_all_covid_confirmed_past_7days', 'COVID_deaths_weekly']]
new_df['COVID_deaths_weekly'] *= 4
new_df = new_df.iloc[-45:]
# plt.ticklabel_format(style='plain')
new_df.plot(figsize=(20, 10), kind="bar")
# Out:
# <Axes: xlabel='week_ending_date'>

# %%
import numpy as np
df1 = pd.DataFrame() # empty data frame
s1 = np.arange(0, 360)
s2 = np.sin(np.radians(s1))
df1.index = s1
df1['sin'] = s2

df1.plot()
plt.axhline(y=0.00, color='r', linestyle='-')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create data
s1 = np.arange(0, 360)
s2 = np.sin(np.radians(s1))
df1 = pd.DataFrame({'sin': s2}, index=s1)

# Plotting
plt.plot(df1.index, df1['sin'], label='Sine Wave')  # Plot sine values
plt.axhline(y=0.00, color='r', linestyle='-', label='Y = 0 Line')  # Horizontal line at y = 0
plt.xlabel('Angle (degrees)')
plt.ylabel('Sine value')
plt.title('Sine Wave from 0 to 360 Degrees')
plt.legend()
plt.grid(True)
plt.show()

# %%
df2 = df1.copy()
df2[df2['sin'] > 0.5] = 0.3
df2[df2['sin'] < -0.5] = -0.8

df2.plot()
# Out:
# <Axes: >

# %%
s3 = pd.Series(np.random.randn(1000)/10)
s4 = s3.cumsum()
s4
# Out:
# 0      0.007699
# 1      0.048502
# 2      0.187290
# 3      0.166278
# 4      0.163206
#          ...
# 995   -0.136919
# 996   -0.096444
# 997   -0.328134
# 998   -0.325542
# 999   -0.296528
# Length: 1000, dtype: float64

# %%
df2['random'] = s4
df2.plot(figsize=(25, 10))
# Out:
# <Axes: >

# %% [markdown]
# #<Center> Homework
# <img src=http://2.bp.blogspot.com/-KJonHReE80I/VDwLlsZXgEI/AAAAAAAAMcc/_nhlmp4Jk5g/s1600/Do%2Byou%2Bwant%2Bme%2Bto%2Beat%2Bit.jpg >
#
# - Download data for 2-3 companies that are related. For example: Nike and Adidas, Honda and Toyota, etc
# - Plot their stock graph on the same figure over the same period of time
# - Do you observe any correlation?
# - You can use yahoo finance to get the data in .csv format <br>
# https://finance.yahoo.com/quote/NKE/history?p=NKE
# - Or you can use the above example

# %%
#@title My Homework - Stock Graph "RTX" vs "LMT"
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Define the ticker symbols for the companies of interest
tickers = ['RTX', 'LMT']  # Raytheon Technologies and Lockheed Martin respectively

# Calculate date 5 years ago from today
end_date = datetime.today()
start_date = end_date - timedelta(days=5*365)

# Download stock data
data = yf.download(tickers, start=start_date, end=end_date)['Adj Close']

# Plot the adjusted closing prices
plt.figure(figsize=(14, 7))
for ticker in tickers:
    plt.plot(data.index, data[ticker], label=f'{ticker} (Adjusted Close)')

plt.title('Comparison of Adjusted Close Prices Over the Last 5 Years: RTX vs LMT')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')
plt.legend()
plt.grid(True)
plt.show()

# Calculate and print the correlation matrix
correlation_matrix = data.corr()
print("Correlation Matrix:\n", correlation_matrix)
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Correlation Matrix:
#  Ticker       LMT       RTX
# Ticker
# LMT     1.000000  0.713263
# RTX     0.713263  1.000000
